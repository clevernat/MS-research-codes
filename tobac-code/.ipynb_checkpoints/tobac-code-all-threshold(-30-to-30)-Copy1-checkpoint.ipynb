# %%
# Standard libraries
import xarray as xr
import numpy as np
import pandas as pd
import os
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
# %matplotlib inline
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import seaborn as sns
import iris
from iris.pandas import as_cubes
import sys

from datetime import datetime
from cartopy.util import add_cyclic_point
import gc
import imageio.v2
from IPython import display
import netCDF4
from global_land_mask import globe
# # Import tobac itself:
import tobac

# Disable a few warnings:
import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)
warnings.filterwarnings('ignore', category=RuntimeWarning, append=True)
warnings.filterwarnings('ignore', category=FutureWarning, append=True)
warnings.filterwarnings('ignore',category=pd.io.pytables.PerformanceWarning)

# %%
# %%time
path = '/glade/u/home/noteng/work/research/data/'
file = 'march13-march14.nc'
data = xr.open_dataset(path+file, )
data = data.sel(time=slice('2020-03-13T04:00:00.000000000', '2020-03-14T05:00:00.000000000'))
data.close()
# Out:
# CPU times: user 37.3 ms, sys: 11.9 ms, total: 49.2 ms
# Wall time: 56.9 ms

# %% [markdown]
# ### equivalent reflectivity factor

# %%
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,450:580,256:771] #Based on longitude and latitude of Andoya and Norwegian Sea
equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,250:650,450:850] #Based on longitude and latitude of Andoya and Norwegian Sea
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,330:580,660:780] #### hdm1 and hdm2
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor']
equivalent_reflectivity_factor
# Out:
# <xarray.DataArray 'equivalent_reflectivity_factor' (time: 301, Yc: 400, Xc: 400)>
# [48160000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2020-03-13T04:00:00 ... 2020-03-14T05:00:00
#   * Xc       (Xc) float32 -8.3e+04 -8.2e+04 -8.1e+04 ... 3.15e+05 3.16e+05
#   * Yc       (Yc) float32 -2.06e+06 -2.061e+06 ... -2.458e+06 -2.459e+06
#     lon      (Yc, Xc) float32 ...
#     lat      (Yc, Xc) float32 ...
# Attributes:
#     standard_name:  equivalent_reflectivity_factor
#     long_name:      Radar Reflectivity
#     units:          dBZ
#     grid_mapping:   projection_lambert

# %% [markdown]
# ### convert equivalent reflectivity factor to Iris cube

# %%
# %%time
ERF = equivalent_reflectivity_factor.to_iris()
ERF
# Out:
# CPU times: user 3.99 s, sys: 246 ms, total: 4.24 s
# Wall time: 4.88 s
# <iris 'Cube' of equivalent_reflectivity_factor / (dBZ) (time: 301; projection_y_coordinate: 400; projection_x_coordinate: 400)>

# %%
# %%time
# Determine temporal and spatial sampling of the input data:
#grid_spacing = 1km... but tobac uses meters... 1000m = 1km
#time_spacing = 5 minutes time resolution... tobac uses seconds..... 
#since our time_spacing is 5 min, we get our time spacing in seconds.. if 60 sec = 1 min? then 5 mins = 300s... so time-spacing is 300
dxy,dt=tobac.utils.get_spacings(ERF, grid_spacing=1000, time_spacing=300)  #tobac detect it by default
dxy, dt
# Out:
# CPU times: user 93 µs, sys: 0 ns, total: 93 µs
# Wall time: 97.8 µs
# (1000, 300)

# %% [markdown]
# # DETECTION FEATURE

# %%
equivalent_reflectivity_factor.max(), equivalent_reflectivity_factor.min()
# Out:
# (<xarray.DataArray 'equivalent_reflectivity_factor' ()>
#  array(48.166157, dtype=float32),
#  <xarray.DataArray 'equivalent_reflectivity_factor' ()>
#  array(-32.408, dtype=float32))

# %%
# Upon experimenting, i found out that threshold of 10, 15 and 20 dBZ performed best or gave the best result
# threshold of 10 was ranked 1st, then 15, 20. Since 10 performed well, we will use that as  target to other things(segmentation-threshold)
# and tracking v-max

# %%
# np.arange(-30, 40, 5)

# %%
# %%time
# threshold = np.arange(-15, 35, 5) 
threshold = np.arange(-32, 35, 5)
# threshold = [-30, -25, -20, -15, -10, -5, 0, 5, 10, 15, 20, 25, 30]
parameters_features = {}
parameters_features['target'] = 'maximum'
parameters_features['threshold'] = threshold
parameters_features['n_min_threshold'] = 0 #set to zero or one always; 
parameters_features['n_erosion_threshold'] = 0 #another filtering/smoothing method.
parameters_features['position_threshold'] ='weighted_diff'
# parameters_features['sigma_threshold'] = 0.1 #smoothing data
# parameters_features['min_distance'] = 15

# Using 'center' here outputs the feature location as the arithmetic center of the detected feature
Features = tobac.feature_detection_multithreshold(field_in=ERF, dxy=dxy, **parameters_features)
# Out:
# CPU times: user 1min 6s, sys: 144 ms, total: 1min 6s
# Wall time: 1min 9s

# %%
# %%time
Features.head()
# Out:
# CPU times: user 211 µs, sys: 1 µs, total: 212 µs
# Wall time: 216 µs
#    frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0      0  462  234.000000  372.000000    1              -12        1
# 1      0  555  193.000000  233.000000    1               -7        2
# 2      0  561  218.254482  295.892979    5               -7        3
# 3      0  565  225.493040  297.124295    3               -7        4
# 4      0  589  297.000000  317.000000    1               -7        5
#
#                   time              timestr  projection_y_coordinate  \
# 0  2020-03-13 04:00:00  2020-03-13 04:00:00            -2.294000e+06
# 1  2020-03-13 04:00:00  2020-03-13 04:00:00            -2.253000e+06
# 2  2020-03-13 04:00:00  2020-03-13 04:00:00            -2.278254e+06
# 3  2020-03-13 04:00:00  2020-03-13 04:00:00            -2.285493e+06
# 4  2020-03-13 04:00:00  2020-03-13 04:00:00            -2.357000e+06
#
#    projection_x_coordinate   latitude  longitude
# 0            289000.000000  69.176064  17.180342
# 1            150000.000000  69.669357  13.809011
# 2            212892.978534  69.394335  15.338539
# 3            214124.295105  69.327628  15.352329
# 4            234000.000000  68.661278  15.669675

# %%
Features.to_csv('../saved-files/threshold-all/Features-all-all1.csv', index=False)

# %%
Features = pd.read_csv("../saved-files/threshold-all/Features-all-all1.csv", chunksize=100)
Features

# %%
cc = []
# Iterate through the chunks
for chunk in Features:
    # Process the data in the current chunk
    # print(chunk)  # This will print the current chunk as a DataFrame
    cc.append(chunk)

# %%
cc[-1]
# Out:
#         frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 136300    300  920  266.000000  318.000000    1               23   136301
# 136301    300  922  274.000000  315.000000    1               23   136302
# 136302    300  923  286.191854  373.098754    7               23   136303
# 136303    300  924  286.000000  350.000000    1               23   136304
# 136311            207930.273276  68.883349  15.088731
# 136312            189000.000000  68.479683  14.538531
# 136313            147396.752678  68.295544  13.508372
# 136314            140834.519203  68.281647  13.349874
# 136315            180868.021091  69.949772  14.658069
# 136316            296274.993033  69.682593  17.544516
# 136317            148000.000000  69.761421  13.775079
# 136318             97506.883698  69.358850  12.438149
# 136319            174000.000000  69.072220  14.294686
# 136320            153000.000000  68.293724  13.641617

# %% [markdown]
# # SEGMENTATION

# %%
# %%time
# Keyword arguments for the segmentation step:
parameters_segmentation={}
parameters_segmentation['target']='maximum'
parameters_segmentation['method']='watershed'
parameters_segmentation['threshold']= -32
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 4.77 µs

# %%
# %%time
# Perform segmentation and save results to files:
Mask_ERF, Features_ERF = tobac.segmentation_2D(Features,ERF,dxy,**parameters_segmentation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/tobac/segmentation.py:297, in segmentation_2D(features, field, dxy, threshold, target, level, method, max_distance, PBC_flag, seed_3D_flag)
#     284 def segmentation_2D(
#     285     features,
#     286     field,
#    (...)
#     294     seed_3D_flag="column",
#     295 ):
#     296     """Wrapper for the segmentation()-function."""
# --> 297     return segmentation(
#     298         features,
#     299         field,
#     300         dxy,
#     301         threshold=threshold,
#     302         target=target,
#     303         level=level,
#     304         method=method,
#     305         max_distance=max_distance,
#     306         PBC_flag=PBC_flag,
#     307         seed_3D_flag=seed_3D_flag,
#     308     )
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/tobac/segmentation.py:1210, in segmentation(features, field, dxy, threshold, target, level, method, max_distance, vertical_coord, PBC_flag, seed_3D_flag, seed_3D_size, segment_number_below_threshold, segment_number_unassigned)
#    1208 for i, field_i in enumerate(field_time):
#    1209     time_i = field_i.coord("time").units.num2date(field_i.coord("time").points[0])
# -> 1210     features_i = features.loc[features["time"] == np.datetime64(time_i)]
#    1211     segmentation_out_i, features_out_i = segmentation_timestep(
#    1212         field_i,
#    1213         features_i,
#    (...)
#    1225         segment_number_below_threshold=segment_number_below_threshold,
#    1226     )
#    1227     segmentation_out_list.append(segmentation_out_i)
#
# AttributeError: 'TextFileReader' object has no attribute 'loc'

# %%
type(Mask_ERF)
# Out:
# iris.cube.Cube

# %%
iris.save(Mask_ERF, '../saved-files/threshold-all/Mask_ERF_iris-all-all1.nc')

# %%
# %%time
Mask_ERF
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 6.44 µs
# <iris 'Cube' of segmentation_mask / (1) (time: 301; projection_y_coordinate: 400; projection_x_coordinate: 400)>

# %%
# %%time
# Convert the segmentation data from iris cube to DataArray
segmented_data = xr.DataArray.from_iris(Mask_ERF)
segmented_data
# Out:
# CPU times: user 2.9 ms, sys: 996 µs, total: 3.89 ms
# Wall time: 3.9 ms
# <xarray.DataArray 'segmentation_mask' (time: 301, Yc: 400, Xc: 400)>
# [48160000 values with dtype=int32]
# Coordinates:
#   * time     (time) datetime64[ns] 2020-03-13T04:00:00 ... 2020-03-14T05:00:00
#   * Yc       (Yc) float32 -2.06e+06 -2.061e+06 ... -2.458e+06 -2.459e+06
#   * Xc       (Xc) float32 -8.3e+04 -8.2e+04 -8.1e+04 ... 3.15e+05 3.16e+05
#     lat      (Yc, Xc) float32 ...
#     lon      (Yc, Xc) float32 ...
# Attributes:
#     long_name:  segmentation_mask

# %%
segmented_data.to_netcdf('../saved-files/threshold-all/segmented_ERF-xr-all-all1.nc')

# %% [markdown]
# # TRAJECTORY LINKING

# %%
# %%time
# keyword arguments for linking step
parameters_linking={}
parameters_linking['v_max']= -32
parameters_linking['stubs']=1
parameters_linking['order']=1
parameters_linking['extrapolate']=0 
parameters_linking['memory']=0
# parameters_linking['adaptive_stop']=0.2
# parameters_linking['adaptive_step']=0.95
# parameters_linking['subnetwork_size']=36
parameters_linking['method_linking']= 'predict'
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs

# %%
# %%time
# Track=tobac.linking_trackpy(Features, ERF, dt=dt, dxy=dxy, **parameters_linking)
Track = tobac.linking_trackpy(Features, ERF, dt=dt, dxy=dxy, **parameters_linking)
# Out:
# ---------------------------------------------------------------------------
# SubnetOversizeException                   Traceback (most recent call last)
# File <timed exec>:2
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/tobac/tracking.py:398, in linking_trackpy(features, field_in, dt, dxy, dz, v_max, d_max, d_min, subnetwork_size, memory, stubs, time_cell_min, order, extrapolate, method_linking, adaptive_step, adaptive_stop, cell_number_start, cell_number_unassigned, vertical_coord, min_h1, max_h1, min_h2, max_h2, PBC_flag)
#     381 trajectories_unfiltered = pred.link_df_iter(
#     382     features_linking_list,
#     383     search_range=search_range,
#    (...)
#     394     #                                 retain_index=False
#     395 )
#     396 # recreate a single dataframe from the list
# --> 398 trajectories_unfiltered = pd.concat(trajectories_unfiltered)
#     400 # change to column names back
#     401 trajectories_unfiltered.rename(
#     402     columns={"y": "hdim_1", "x": "hdim_2", "z": "vdim_adj"}, inplace=True
#     403 )
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/pandas/core/reshape/concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/pandas/core/reshape/concat.py:426, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     424     objs = [objs[k] for k in keys]
#     425 else:
# --> 426     objs = list(objs)
#     428 if len(objs) == 0:
#     429     raise ValueError("No objects to concatenate")
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/predict.py:83, in NullPredict.wrap(self, linking_fcn, *args, **kw)
#      80 kw['pos_columns'] = self.pos_columns
#      82 self.t_column = kw.get('t_column', 'frame')
# ---> 83 for frame in linking_fcn(*args, **kw):
#      84     self.observe(frame)
#      85     yield frame
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/linking/linking.py:278, in link_df_iter(f_iter, search_range, pos_columns, t_column, **kwargs)
#     274 coords_iter = coords_from_df_iter(f_coords_iter, pos_columns, t_column)
#     276 ids_iter = (_ids for _i, _ids in
#     277     link_iter(coords_iter, search_range, **kwargs))
# --> 278 for df, ids in zip(f_iter, ids_iter):
#     279     df_linked = df.copy()
#     280     df_linked['particle'] = ids
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/linking/linking.py:276, in <genexpr>(.0)
#     273 f_iter, f_coords_iter = itertools.tee(f_iter)
#     274 coords_iter = coords_from_df_iter(f_coords_iter, pos_columns, t_column)
# --> 276 ids_iter = (_ids for _i, _ids in
#     277     link_iter(coords_iter, search_range, **kwargs))
#     278 for df, ids in zip(f_iter, ids_iter):
#     279     df_linked = df.copy()
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/linking/linking.py:102, in link_iter(coords_iter, search_range, **kwargs)
#      99 yield t, linker.particle_ids
#     101 for t, coords in coords_iter:
# --> 102     linker.next_level(coords, t)
#     103     logger.info("Frame {}: {} trajectories present.".format(t, len(linker.particle_ids)))
#     104     yield t, linker.particle_ids
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/linking/linking.py:511, in Linker.next_level(self, coords, t, extra_data)
#     507 prev_hash = self.update_hash(coords, t, extra_data)
#     509 self.subnets = Subnets(prev_hash, self.hash, self.search_range,
#     510                        self.MAX_NEIGHBORS)
# --> 511 spl, dpl = self.assign_links()
#     512 self.apply_links(spl, dpl)
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/linking/linking.py:520, in Linker.assign_links(self)
#     517 for sp in source_set:
#     518     sp.forward_cands.sort(key=lambda x: x[1])
# --> 520 sn_spl, sn_dpl = self.subnet_linker(source_set, dest_set,
#     521                                     self.search_range)
#     522 spl.extend(sn_spl)
#     523 dpl.extend(sn_dpl)
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/linking/subnetlinker.py:390, in subnet_linker_recursive(source_set, dest_set, search_range, **kwargs)
#     387 for _s in source_set:
#     388     _s.forward_cands.append((None, search_range))
# --> 390 snl = SubnetLinker(source_set, len(dest_set), search_range, **kwargs)
#     391 sn_spl, sn_dpl = [list(particles) for particles in zip(*snl.best_pairs)]
#     393 for dp in dest_set - set(sn_dpl):
#     394     # Unclaimed destination particle in subnet
#
# File /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/trackpy/linking/subnetlinker.py:41, in SubnetLinker.__init__(self, s_sn, dest_size, search_range, max_size)
#      38 self.cur_sum = 0
#      40 if self.MAX > self.max_size:
# ---> 41     raise SubnetOversizeException("Subnetwork contains %d points"
#      42                                   % self.MAX)
#      43 # do the computation
#      44 self.do_recur(0)
#
# SubnetOversizeException: Subnetwork contains 1470 points

# %%
#

# %%
Track.to_csv('../saved-files/threshold-all/Track-all-all.csv', index=False)

# %%
# latA = 69.141281 #latitude of COMBLE site
# lonA = 15.684166-1 #longitude of COMBLE site -1

# %% [markdown]
