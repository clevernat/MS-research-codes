# %%
# Standard libraries
import xarray as xr
import numpy as np
import pandas as pd
import os
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
# %matplotlib inline
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import seaborn as sns
import iris
from iris.pandas import as_cubes
import sys

from datetime import datetime
from cartopy.util import add_cyclic_point
import gc
import imageio.v2
from IPython import display
import netCDF4
from global_land_mask import globe
# # Import tobac itself:
import tobac

# Disable a few warnings:
import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)
warnings.filterwarnings('ignore', category=RuntimeWarning, append=True)
warnings.filterwarnings('ignore', category=FutureWarning, append=True)
warnings.filterwarnings('ignore',category=pd.io.pytables.PerformanceWarning)

# %%
# %%time
path = '/glade/u/home/noteng/work/research/data/'
file = 'march13-march14.nc'
data = xr.open_dataset(path+file)
data.close()
# Out:
# CPU times: user 26 ms, sys: 8.3 ms, total: 34.3 ms
# Wall time: 57 ms

# %% [markdown]
# ### equivalent reflectivity factor

# %%
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,450:580,256:771] #Based on longitude and latitude of Andoya and Norwegian Sea
equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,250:650,450:850] #Based on longitude and latitude of Andoya and Norwegian Sea
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,330:580,660:780] #### hdm1 and hdm2
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor']
equivalent_reflectivity_factor
# Out:
# <xarray.DataArray 'equivalent_reflectivity_factor' (time: 360, Yc: 400, Xc: 400)>
# [57600000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2020-03-13 ... 2020-03-14T05:55:00
#   * Xc       (Xc) float32 -8.3e+04 -8.2e+04 -8.1e+04 ... 3.15e+05 3.16e+05
#   * Yc       (Yc) float32 -2.06e+06 -2.061e+06 ... -2.458e+06 -2.459e+06
#     lon      (Yc, Xc) float32 ...
#     lat      (Yc, Xc) float32 ...
# Attributes:
#     standard_name:  equivalent_reflectivity_factor
#     long_name:      Radar Reflectivity
#     units:          dBZ
#     grid_mapping:   projection_lambert

# %% [markdown]
# ### convert equivalent reflectivity factor to Iris cube

# %%
# %%time
ERF = equivalent_reflectivity_factor.to_iris()
ERF
# Out:
# CPU times: user 5.74 s, sys: 234 ms, total: 5.98 s
# Wall time: 6.04 s
# <iris 'Cube' of equivalent_reflectivity_factor / (dBZ) (time: 360; projection_y_coordinate: 400; projection_x_coordinate: 400)>

# %%
# %%time
# Determine temporal and spatial sampling of the input data:
#grid_spacing = 1km... but tobac uses meters... 1000m = 1km
#time_spacing = 5 minutes time resolution... tobac uses seconds..... 
#since our time_spacing is 5 min, we get our time spacing in seconds.. if 60 sec = 1 min? then 5 mins = 300s... so time-spacing is 300
dxy,dt=tobac.utils.get_spacings(ERF, grid_spacing=1000, time_spacing=300)  #tobac detect it by default
dxy, dt
# Out:
# CPU times: user 108 µs, sys: 12 µs, total: 120 µs
# Wall time: 126 µs
# (1000, 300)

# %% [markdown]
# # DETECTION FEATURE

# %%
# %%time
# threshold = np.arange(5, 20.1, 1)
threshold = [20]
parameters_features = {}
parameters_features['target'] = 'maximum'
parameters_features['threshold'] = threshold
parameters_features['n_min_threshold'] = 0 #set to zero or one always; 
parameters_features['n_erosion_threshold'] = 0 #another filtering/smoothing method.
parameters_features['position_threshold'] ='weighted_diff'
parameters_features['sigma_threshold'] = 1 #smoothing data
# parameters_features['min_distance'] = 15

# Using 'center' here outputs the feature location as the arithmetic center of the detected feature
Features = tobac.feature_detection_multithreshold(field_in=ERF, dxy=dxy, **parameters_features)
# Out:
# CPU times: user 5.13 s, sys: 35 ms, total: 5.17 s
# Wall time: 5.38 s

# %%
# %%time
Features.head()
# Out:
# CPU times: user 400 µs, sys: 0 ns, total: 400 µs
# Wall time: 344 µs
#    frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0      0    1  122.000000  311.000000    1               20        1
# 1      0    2  133.000000  296.000000    1               20        2
# 2      0    3  149.000000  280.396410    2               20        3
# 3      0    4  157.064783  268.557552   47               20        4
# 4      0    5  154.000000  290.000000    1               20        5
#
#                   time              timestr  projection_y_coordinate  \
# 0  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.182000e+06
# 1  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.193000e+06
# 2  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.209000e+06
# 3  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.217065e+06
# 4  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.214000e+06
#
#    projection_x_coordinate   latitude  longitude
# 0            228000.000000  70.252899  15.965262
# 1            213000.000000  70.167007  15.547579
# 2            197396.410106  70.035210  15.106392
# 3            185557.551696  69.971369  14.784228
# 4            207000.000000  69.981934  15.341394

# %%
Features.to_csv('../saved-files/threshold-20/Features-20.csv', index=False)

# %% [markdown]
# # SEGMENTATION

# %%
# %%time
# Keyword arguments for the segmentation step:
parameters_segmentation={}
parameters_segmentation['target']='maximum'
parameters_segmentation['method']='watershed'
parameters_segmentation['threshold']=20
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.11 µs

# %%
# %%time
# Perform segmentation and save results to files:
Mask_ERF, Features_ERF = tobac.segmentation_2D(Features,ERF,dxy,**parameters_segmentation)
# Out:
# CPU times: user 11.7 s, sys: 344 ms, total: 12.1 s
# Wall time: 12.3 s

# %%
type(Mask_ERF)
# Out:
# iris.cube.Cube

# %%
iris.save(Mask_ERF, '../saved-files/threshold-20/Mask_ERF_iris-20.nc')

# %%
# %%time
Mask_ERF
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 6.91 µs
# <iris 'Cube' of segmentation_mask / (1) (time: 360; projection_y_coordinate: 400; projection_x_coordinate: 400)>

# %%
# %%time
# Convert the segmentation data from iris cube to DataArray
segmented_data = xr.DataArray.from_iris(Mask_ERF)
segmented_data
# Out:
# CPU times: user 3.96 ms, sys: 0 ns, total: 3.96 ms
# Wall time: 3.85 ms
# <xarray.DataArray 'segmentation_mask' (time: 360, Yc: 400, Xc: 400)>
# [57600000 values with dtype=int32]
# Coordinates:
#   * time     (time) datetime64[ns] 2020-03-13 ... 2020-03-14T05:55:00
#   * Yc       (Yc) float32 -2.06e+06 -2.061e+06 ... -2.458e+06 -2.459e+06
#   * Xc       (Xc) float32 -8.3e+04 -8.2e+04 -8.1e+04 ... 3.15e+05 3.16e+05
#     lat      (Yc, Xc) float32 ...
#     lon      (Yc, Xc) float32 ...
# Attributes:
#     long_name:  segmentation_mask

# %%
segmented_data.to_netcdf('../saved-files/threshold-20/segmented_ERF-xr-20.nc')

# %% [markdown]
# # TRAJECTORY LINKING

# %%
# %%time
# keyword arguments for linking step
parameters_linking={}
parameters_linking['v_max']=20
parameters_linking['stubs']=1
parameters_linking['order']=1
parameters_linking['extrapolate']=0 
parameters_linking['memory']=0
parameters_linking['adaptive_stop']=0.2
parameters_linking['adaptive_step']=0.95
parameters_linking['subnetwork_size']=15
parameters_linking['method_linking']= 'predict'
# parameters_linking['time_cell_min'] = 10
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 7.87 µs

# %%
# %%time
# Track=tobac.linking_trackpy(Features, ERF, dt=dt, dxy=dxy, **parameters_linking)
Track = tobac.linking_trackpy(Features, ERF, dt=dt, dxy=dxy, **parameters_linking)
# Out:
# Frame 359: 14 trajectories present.
# CPU times: user 3.78 s, sys: 182 ms, total: 3.96 s
# Wall time: 3.79 s

# %%
Track.to_csv('../saved-files/threshold-20/Track-20.csv', index=False)

# %%
# latA = 69.141281 #latitude of COMBLE site
# lonA = 15.684166-1 #longitude of COMBLE site -1

# %% [markdown]
# <h1 style="color:red;">TRACKED INFO</h1>

# %%
Track
# Out:
#        frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0          0    1  122.000000  311.000000    1               20        1
# 1          0    2  133.000000  296.000000    1               20        2
# 2          0    3  149.000000  280.396410    2               20        3
# 3          0    4  157.064783  268.557552   47               20        4
# 4          0    5  154.000000  290.000000    1               20        5
# ...      ...  ...         ...         ...  ...              ...      ...
# 18004    359   10  241.935201  232.935201    2               20    18005
# 18005    359   11  245.975105  286.627720   54               20    18006
# 18006    359   12  244.471325  276.893097    5               20    18007
# 18007    359   13  264.083255  280.766181    5               20    18008
# 18008    359   14  277.427447  341.038215   42               20    18009
#
#                       time              timestr  projection_y_coordinate  \
# 0      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.182000e+06
# 1      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.193000e+06
# 2      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.209000e+06
# 3      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.217065e+06
# 4      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.214000e+06
# ...                    ...                  ...                      ...
# 18004  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.301935e+06
# 18005  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.305975e+06
# 18006  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.304471e+06
# 18007  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.324083e+06
# 18008  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.337427e+06
#
#        projection_x_coordinate   latitude  longitude  cell       time_cell
# 0                228000.000000  70.252899  15.965262     1 0 days 00:00:00
# 1                213000.000000  70.167007  15.547579     2 0 days 00:00:00
# 2                197396.410106  70.035210  15.106392     3 0 days 00:00:00
# 3                185557.551696  69.971369  14.784228     4 0 days 00:00:00
# 4                207000.000000  69.981934  15.341394     5 0 days 00:00:00
# ...                        ...        ...        ...   ...             ...
# 18004            149935.200705  69.224543  13.726663  4659 0 days 00:05:00
# 18005            203627.720262  69.150396  15.046379  4648 0 days 00:20:00
# 18006            193893.096905  69.171675  14.809412  4662 0 days 00:00:00
# 18007            197766.181461  68.990551  14.863826  4652 0 days 00:15:00
# 18008            258038.215072  68.815973  16.299609  4623 0 days 01:00:00
#
# [18009 rows x 15 columns]

# %% [markdown]
# # Sort Tracked info based on cell_id and time

# %%
# %%time
track = Track.sort_values(['cell', 'time_cell'])
track = track.reset_index(drop=True)
track.head()
# Out:
# CPU times: user 11.9 ms, sys: 0 ns, total: 11.9 ms
# Wall time: 10.7 ms
#    frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0      0    1  122.000000  311.000000    1               20        1
# 1      0    2  133.000000  296.000000    1               20        2
# 2      0    3  149.000000  280.396410    2               20        3
# 3      1    3  153.000000  283.624139    2               20       47
# 4      2    5  157.296877  282.501119    4               20       95
#
#                   time              timestr  projection_y_coordinate  \
# 0  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.182000e+06
# 1  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.193000e+06
# 2  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.209000e+06
# 3  2020-03-13 00:05:00  2020-03-13 00:05:00            -2.213000e+06
# 4  2020-03-13 00:10:00  2020-03-13 00:10:00            -2.217297e+06
#
#    projection_x_coordinate   latitude  longitude  cell       time_cell
# 0            228000.000000  70.252899  15.965262     1 0 days 00:00:00
# 1            213000.000000  70.167007  15.547579     2 0 days 00:00:00
# 2            197396.410106  70.035210  15.106392     3 0 days 00:00:00
# 3            200624.139265  69.996320  15.180108     3 0 days 00:05:00
# 4            199501.119196  69.958285  15.141340     3 0 days 00:10:00

# %%
track.to_csv('../saved-files/threshold-20/track-reset-20.csv', index=False)

# %%
# track = pd.read_csv('saved-files/track-reset.csv')

# %%
track.head()
# Out:
#    frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0      0    1  122.000000  311.000000    1               20        1
# 1      0    2  133.000000  296.000000    1               20        2
# 2      0    3  149.000000  280.396410    2               20        3
# 3      1    3  153.000000  283.624139    2               20       47
# 4      2    5  157.296877  282.501119    4               20       95
#
#                   time              timestr  projection_y_coordinate  \
# 0  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.182000e+06
# 1  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.193000e+06
# 2  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.209000e+06
# 3  2020-03-13 00:05:00  2020-03-13 00:05:00            -2.213000e+06
# 4  2020-03-13 00:10:00  2020-03-13 00:10:00            -2.217297e+06
#
#    projection_x_coordinate   latitude  longitude  cell       time_cell
# 0            228000.000000  70.252899  15.965262     1 0 days 00:00:00
# 1            213000.000000  70.167007  15.547579     2 0 days 00:00:00
# 2            197396.410106  70.035210  15.106392     3 0 days 00:00:00
# 3            200624.139265  69.996320  15.180108     3 0 days 00:05:00
# 4            199501.119196  69.958285  15.141340     3 0 days 00:10:00

# %% [markdown]
# <h1 style="color:red;  text-align: center;">END OF TRACK</h1>
