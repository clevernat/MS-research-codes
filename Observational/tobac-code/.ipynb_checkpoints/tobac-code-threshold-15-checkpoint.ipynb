# %%
# Standard libraries
import xarray as xr
import numpy as np
import pandas as pd
import os
from glob import glob
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
# %matplotlib inline
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import seaborn as sns
import iris
from iris.pandas import as_cubes
import sys

from datetime import datetime
from cartopy.util import add_cyclic_point
import gc
import imageio.v2
from IPython import display
import netCDF4
from global_land_mask import globe
# # Import tobac itself:
import tobac

# Disable a few warnings:
import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)
warnings.filterwarnings('ignore', category=RuntimeWarning, append=True)
warnings.filterwarnings('ignore', category=FutureWarning, append=True)
warnings.filterwarnings('ignore',category=pd.io.pytables.PerformanceWarning)

# %%
# %%time
path = '/glade/u/home/noteng/work/research/data/'
file = 'march13-march14.nc'
data = xr.open_dataset(path+file)
data.close()
# Out:
# CPU times: user 29.7 ms, sys: 11.7 ms, total: 41.4 ms
# Wall time: 66.7 ms

# %% [markdown]
# ### equivalent reflectivity factor

# %%
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,450:580,256:771] #Based on longitude and latitude of Andoya and Norwegian Sea
equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,250:650,450:850] #Based on longitude and latitude of Andoya and Norwegian Sea
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor'][:,330:580,660:780] #### hdm1 and hdm2
# equivalent_reflectivity_factor = data['equivalent_reflectivity_factor']
equivalent_reflectivity_factor
# Out:
# <xarray.DataArray 'equivalent_reflectivity_factor' (time: 360, Yc: 400, Xc: 400)>
# [57600000 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2020-03-13 ... 2020-03-14T05:55:00
#   * Xc       (Xc) float32 -8.3e+04 -8.2e+04 -8.1e+04 ... 3.15e+05 3.16e+05
#   * Yc       (Yc) float32 -2.06e+06 -2.061e+06 ... -2.458e+06 -2.459e+06
#     lon      (Yc, Xc) float32 ...
#     lat      (Yc, Xc) float32 ...
# Attributes:
#     standard_name:  equivalent_reflectivity_factor
#     long_name:      Radar Reflectivity
#     units:          dBZ
#     grid_mapping:   projection_lambert

# %% [markdown]
# ### convert equivalent reflectivity factor to Iris cube

# %%
# %%time
ERF = equivalent_reflectivity_factor.to_iris()
ERF
# Out:
# CPU times: user 5.76 s, sys: 304 ms, total: 6.07 s
# Wall time: 6.17 s
# <iris 'Cube' of equivalent_reflectivity_factor / (dBZ) (time: 360; projection_y_coordinate: 400; projection_x_coordinate: 400)>

# %%
# %%time
# Determine temporal and spatial sampling of the input data:
#grid_spacing = 1km... but tobac uses meters... 1000m = 1km
#time_spacing = 5 minutes time resolution... tobac uses seconds..... 
#since our time_spacing is 5 min, we get our time spacing in seconds.. if 60 sec = 1 min? then 5 mins = 300s... so time-spacing is 300
dxy,dt=tobac.utils.get_spacings(ERF, grid_spacing=1000, time_spacing=300)  #tobac detect it by default
dxy, dt
# Out:
# CPU times: user 63 µs, sys: 6 µs, total: 69 µs
# Wall time: 72.7 µs
# (1000, 300)

# %% [markdown]
# # DETECTION FEATURE

# %%
# %%time
# threshold = np.arange(5, 20.1, 1)
threshold = [15]
parameters_features = {}
parameters_features['target'] = 'maximum'
parameters_features['threshold'] = threshold
parameters_features['n_min_threshold'] = 0 #set to zero or one always; 
parameters_features['n_erosion_threshold'] = 0 #another filtering/smoothing method.
parameters_features['position_threshold'] ='weighted_diff'
parameters_features['sigma_threshold'] = 1 #smoothing data
# parameters_features['min_distance'] = 15

# Using 'center' here outputs the feature location as the arithmetic center of the detected feature
Features = tobac.feature_detection_multithreshold(field_in=ERF, dxy=dxy, **parameters_features)
# Out:
# CPU times: user 6.77 s, sys: 31.8 ms, total: 6.8 s
# Wall time: 6.8 s

# %%
# %%time
Features.head()
# Out:
# CPU times: user 125 µs, sys: 6 µs, total: 131 µs
# Wall time: 122 µs
#    frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0      0    1  121.134456  311.787628    6               15        1
# 1      0    2  124.000000  308.000000    1               15        2
# 2      0    3  127.141568  302.872817   13               15        3
# 3      0    4  133.146195  296.225597   21               15        4
# 4      0    5  136.097456  311.316981   40               15        5
#
#                   time              timestr  projection_y_coordinate  \
# 0  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.181134e+06
# 1  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.184000e+06
# 2  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.187142e+06
# 3  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.193146e+06
# 4  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.196097e+06
#
#    projection_x_coordinate   latitude  longitude
# 0            228787.627890  70.259986  15.988078
# 1            225000.000000  70.237617  15.881973
# 2            219872.816908  70.213906  15.740644
# 3            213225.596906  70.165484  15.553050
# 4            228316.981326  70.125018  15.935425

# %%
Features.to_csv('../saved-files/threshold-15/Features-15.csv', index=False)

# %% [markdown]
# # SEGMENTATION

# %%
# %%time
# Keyword arguments for the segmentation step:
parameters_segmentation={}
parameters_segmentation['target']='maximum'
parameters_segmentation['method']='watershed'
parameters_segmentation['threshold']=15
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.72 µs

# %%
# %%time
# Perform segmentation and save results to files:
Mask_ERF, Features_ERF = tobac.segmentation_2D(Features,ERF,dxy,**parameters_segmentation)
# Out:
# CPU times: user 16 s, sys: 403 ms, total: 16.4 s
# Wall time: 16.4 s

# %%
type(Mask_ERF)
# Out:
# iris.cube.Cube

# %%
iris.save(Mask_ERF, '../saved-files/threshold-15/Mask_ERF_iris-15.nc')

# %%
# %%time
Mask_ERF
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 6.2 µs
# <iris 'Cube' of segmentation_mask / (1) (time: 360; projection_y_coordinate: 400; projection_x_coordinate: 400)>

# %%
# %%time
# Convert the segmentation data from iris cube to DataArray
segmented_data = xr.DataArray.from_iris(Mask_ERF)
segmented_data
# Out:
# CPU times: user 3.65 ms, sys: 0 ns, total: 3.65 ms
# Wall time: 3.59 ms
# <xarray.DataArray 'segmentation_mask' (time: 360, Yc: 400, Xc: 400)>
# [57600000 values with dtype=int32]
# Coordinates:
#   * time     (time) datetime64[ns] 2020-03-13 ... 2020-03-14T05:55:00
#   * Yc       (Yc) float32 -2.06e+06 -2.061e+06 ... -2.458e+06 -2.459e+06
#   * Xc       (Xc) float32 -8.3e+04 -8.2e+04 -8.1e+04 ... 3.15e+05 3.16e+05
#     lat      (Yc, Xc) float32 ...
#     lon      (Yc, Xc) float32 ...
# Attributes:
#     long_name:  segmentation_mask

# %%
segmented_data.to_netcdf('../saved-files/threshold-15/segmented_ERF-xr-15.nc')

# %% [markdown]
# # TRAJECTORY LINKING

# %%
# %%time
# keyword arguments for linking step
parameters_linking={}
parameters_linking['v_max']=15
parameters_linking['stubs']=1
parameters_linking['order']=1
parameters_linking['extrapolate']=0 
parameters_linking['memory']=0
parameters_linking['adaptive_stop']=0.2
parameters_linking['adaptive_step']=0.95
parameters_linking['subnetwork_size']=15
parameters_linking['method_linking']= 'predict'
# parameters_linking['time_cell_min'] = 10
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 7.39 µs

# %%
# %%time
# Track=tobac.linking_trackpy(Features, ERF, dt=dt, dxy=dxy, **parameters_linking)
Track = tobac.linking_trackpy(Features, ERF, dt=dt, dxy=dxy, **parameters_linking)
# Out:
# Frame 359: 31 trajectories present.
# CPU times: user 4.21 s, sys: 145 ms, total: 4.35 s
# Wall time: 4.23 s

# %%
Track.to_csv('../saved-files/threshold-15/Track-15.csv', index=False)

# %%
# latA = 69.141281 #latitude of COMBLE site
# lonA = 15.684166-1 #longitude of COMBLE site -1

# %% [markdown]
# <h1 style="color:red;">TRACKED INFO</h1>

# %%
Track
# Out:
#        frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0          0    1  121.134456  311.787628    6               15        1
# 1          0    2  124.000000  308.000000    1               15        2
# 2          0    3  127.141568  302.872817   13               15        3
# 3          0    4  133.146195  296.225597   21               15        4
# 4          0    5  136.097456  311.316981   40               15        5
# ...      ...  ...         ...         ...  ...              ...      ...
# 26900    359   27  276.453757  324.109619   32               15    26901
# 26901    359   28  277.545178  341.106198   46               15    26902
# 26902    359   29  285.184241  313.093541   25               15    26903
# 26903    359   30  311.936269  240.000000    2               15    26904
# 26904    359   31  346.870455  244.091290   57               15    26905
#
#                       time              timestr  projection_y_coordinate  \
# 0      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.181134e+06
# 1      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.184000e+06
# 2      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.187142e+06
# 3      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.193146e+06
# 4      2020-03-13 00:00:00  2020-03-13 00:00:00            -2.196097e+06
# ...                    ...                  ...                      ...
# 26900  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.336454e+06
# 26901  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.337545e+06
# 26902  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.345184e+06
# 26903  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.371936e+06
# 26904  2020-03-14 05:55:00  2020-03-14 05:55:00            -2.406870e+06
#
#        projection_x_coordinate   latitude  longitude  cell       time_cell
# 0                228787.627890  70.259986  15.988078     1 0 days 00:00:00
# 1                225000.000000  70.237617  15.881973     2 0 days 00:00:00
# 2                219872.816908  70.213906  15.740644     3 0 days 00:00:00
# 3                213225.596906  70.165484  15.553050     4 0 days 00:00:00
# 4                228316.981326  70.125018  15.935425     5 0 days 00:00:00
# ...                        ...        ...        ...   ...             ...
# 26900            241109.619074  68.841202  15.891765  8084 0 days 00:00:00
# 26901            258106.198387  68.814838  16.300940  8085 0 days 00:00:00
# 26902            230093.540722  68.772034  15.603539  8065 0 days 00:15:00
# 26903            157000.000000  68.583367  13.786921  8076 0 days 00:10:00
# 26904            161091.289501  68.262767  13.829082  7942 0 days 01:25:00
#
# [26905 rows x 15 columns]

# %% [markdown]
# # Sort Tracked info based on cell_id and time

# %%
# %%time
track = Track.sort_values(['cell', 'time_cell'])
track = track.reset_index(drop=True)
track.head()
# Out:
# CPU times: user 13.7 ms, sys: 0 ns, total: 13.7 ms
# Wall time: 12.5 ms
#    frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0      0    1  121.134456  311.787628    6               15        1
# 1      0    2  124.000000  308.000000    1               15        2
# 2      1    1  127.687600  308.064196   38               15       83
# 3      2    4  131.334708  308.442257   45               15      178
# 4      3    4  133.462202  311.013185   27               15      263
#
#                   time              timestr  projection_y_coordinate  \
# 0  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.181134e+06
# 1  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.184000e+06
# 2  2020-03-13 00:05:00  2020-03-13 00:05:00            -2.187688e+06
# 3  2020-03-13 00:10:00  2020-03-13 00:10:00            -2.191335e+06
# 4  2020-03-13 00:15:00  2020-03-13 00:15:00            -2.193462e+06
#
#    projection_x_coordinate   latitude  longitude  cell       time_cell
# 0            228787.627890  70.259986  15.988078     1 0 days 00:00:00
# 1            225000.000000  70.237617  15.881973     2 0 days 00:00:00
# 2            225064.196229  70.204183  15.873792     2 0 days 00:05:00
# 3            225442.257490  70.170818  15.873866     2 0 days 00:10:00
# 4            228013.184615  70.149156  15.934654     2 0 days 00:15:00

# %%
track.to_csv('../saved-files/threshold-15/track-reset-15.csv', index=False)

# %%
# track = pd.read_csv('saved-files/track-reset.csv')

# %%
track.head()
# Out:
#    frame  idx      hdim_1      hdim_2  num  threshold_value  feature  \
# 0      0    1  121.134456  311.787628    6               15        1
# 1      0    2  124.000000  308.000000    1               15        2
# 2      1    1  127.687600  308.064196   38               15       83
# 3      2    4  131.334708  308.442257   45               15      178
# 4      3    4  133.462202  311.013185   27               15      263
#
#                   time              timestr  projection_y_coordinate  \
# 0  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.181134e+06
# 1  2020-03-13 00:00:00  2020-03-13 00:00:00            -2.184000e+06
# 2  2020-03-13 00:05:00  2020-03-13 00:05:00            -2.187688e+06
# 3  2020-03-13 00:10:00  2020-03-13 00:10:00            -2.191335e+06
# 4  2020-03-13 00:15:00  2020-03-13 00:15:00            -2.193462e+06
#
#    projection_x_coordinate   latitude  longitude  cell       time_cell
# 0            228787.627890  70.259986  15.988078     1 0 days 00:00:00
# 1            225000.000000  70.237617  15.881973     2 0 days 00:00:00
# 2            225064.196229  70.204183  15.873792     2 0 days 00:05:00
# 3            225442.257490  70.170818  15.873866     2 0 days 00:10:00
# 4            228013.184615  70.149156  15.934654     2 0 days 00:15:00

# %% [markdown]
# <h1 style="color:red;  text-align: center;">END OF TRACK</h1>
