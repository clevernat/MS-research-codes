# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.ticker import FixedLocator, FixedFormatter

# %%
first_landfall_threshold_10 = pd.read_csv('./saved-files/threshold-10/all-cells-first_landfall-threshold-10.csv')
first_landfall_threshold_15 = pd.read_csv('./saved-files/threshold-15/all-cells-first_landfall-threshold-15.csv')
first_landfall_threshold_20 = pd.read_csv('./saved-files/threshold-20/all-cells-first_landfall-threshold-20.csv')

# %%
len(first_landfall_threshold_10), len(first_landfall_threshold_15), len(first_landfall_threshold_20)
# Out:
# (1381, 2049, 1606)

# %%
# Changing to datetime format
first_landfall_threshold_10['timestr'] = pd.to_datetime(first_landfall_threshold_10['timestr'])
first_landfall_threshold_15['timestr'] = pd.to_datetime(first_landfall_threshold_15['timestr'])
first_landfall_threshold_20['timestr'] = pd.to_datetime(first_landfall_threshold_20['timestr'])

# %%
# Selecting time from 4am on the 13th March to 5am on the 14th March
first_landfall_threshold_10 = first_landfall_threshold_10[first_landfall_threshold_10['timestr'] >= '2020-03-13 04:00:00']
first_landfall_threshold_15 = first_landfall_threshold_15[first_landfall_threshold_15['timestr'] >= '2020-03-13 04:00:00']
first_landfall_threshold_20 = first_landfall_threshold_20[first_landfall_threshold_20['timestr'] >= '2020-03-13 04:00:00']

# %%
len(first_landfall_threshold_10), len(first_landfall_threshold_15), len(first_landfall_threshold_20)
# Out:
# (1381, 2049, 1606)

# %% [markdown]
# ### _PERFORMING STATISTICS ON CELL_

# %%
# max dBZ
mean_max_dBZ_threshold_20 = []
std_max_dBZ_threshold_20 = []
rel_times_threshold_20 = []

# mean dBZ
mean_mean_dBZ_threshold_20 = []
std_mean_dBZ_threshold_20 = []
rel_times1_threshold_20 = []

# area
percentiles_25_area_threshold_20 = []
percentiles_50_area_threshold_20 = []
percentiles_75_area_threshold_20 = []
rel_times_area_threshold_20 = []

for indexes, time in enumerate(np.unique(first_landfall_threshold_20['relative_time'])):
    # Sorting based on same relative times
    sort_relative_times_threshold_20 = first_landfall_threshold_20[first_landfall_threshold_20['relative_time'] == time]
    # Find each relative time associated with a particular reflectivity value
   
    mean_threshold_20 = np.mean(sort_relative_times_threshold_20['max dBZ'].values)
    means_threshold_20 = np.mean(sort_relative_times_threshold_20['mean dBZ'].values)
    
    std_threshold_20 = np.std(sort_relative_times_threshold_20['max dBZ'].values)
    stds_threshold_20 = np.std(sort_relative_times_threshold_20['mean dBZ'].values)
    
    
    # AREA
    # 25th percentile
    percentile_25_threshold_20 = np.nanpercentile(sort_relative_times_threshold_20['area($km^2$)'].values, 25)
     # 50th percentile
    percentile_50_threshold_20 = np.nanpercentile(sort_relative_times_threshold_20['area($km^2$)'].values, 50)
    # 75th percentile
    percentile_75_threshold_20 = np.nanpercentile(sort_relative_times_threshold_20['area($km^2$)'].values, 75)
    
       
    # 25th percentile
    percentiles_25_area_threshold_20.append(percentile_25_threshold_20)
    # 50th percentile
    percentiles_50_area_threshold_20.append(percentile_50_threshold_20)
    # 75th percentile
    percentiles_75_area_threshold_20.append(percentile_75_threshold_20)
    
    mean_max_dBZ_threshold_20.append(mean_threshold_20)
    mean_mean_dBZ_threshold_20.append(means_threshold_20)
    
    std_max_dBZ_threshold_20.append(std_threshold_20)
    std_mean_dBZ_threshold_20.append(stds_threshold_20)
    
    rel_time_threshold_20 = np.mean(sort_relative_times_threshold_20['relative_time'].values)
    rel_times_threshold_20.append(rel_time_threshold_20)
    rel_times1_threshold_20.append(rel_time_threshold_20)
    # time
    rel_times_area_threshold_20.append(rel_time_threshold_20)

# %%
# max dBZ
mean_max_dBZ_threshold_15 = []
std_max_dBZ_threshold_15 = []
rel_times_threshold_15 = []

# mean dBZ
mean_mean_dBZ_threshold_15 = []
std_mean_dBZ_threshold_15 = []
rel_times1_threshold_15 = []

# area
percentiles_25_area_threshold_15 = []
percentiles_50_area_threshold_15 = []
percentiles_75_area_threshold_15 = []
rel_times_area_threshold_15 = []

for indexes, time in enumerate(np.unique(first_landfall_threshold_15['relative_time'])):
    # Sorting based on same relative times
    sort_relative_times_threshold_15 = first_landfall_threshold_15[first_landfall_threshold_15['relative_time'] == time]
    # Find each relative time associated with a particular reflectivity value
    
    mean_threshold_15 = np.mean(sort_relative_times_threshold_15['max dBZ'].values)
    means_threshold_15 = np.mean(sort_relative_times_threshold_15['mean dBZ'].values)
   
    
    std_threshold_15 = np.std(sort_relative_times_threshold_15['max dBZ'].values)
    stds_threshold_15 = np.std(sort_relative_times_threshold_15['mean dBZ'].values)
    
    
    # AREA
    # 25th percentile
    percentile_25_threshold_15 = np.nanpercentile(sort_relative_times_threshold_15['area($km^2$)'].values, 25)
     # 50th percentile
    percentile_50_threshold_15 = np.nanpercentile(sort_relative_times_threshold_15['area($km^2$)'].values, 50)
    # 75th percentile
    percentile_75_threshold_15 = np.nanpercentile(sort_relative_times_threshold_15['area($km^2$)'].values, 75)
    
       
    # 25th percentile
    percentiles_25_area_threshold_15.append(percentile_25_threshold_15)
    # 50th percentile
    percentiles_50_area_threshold_15.append(percentile_50_threshold_15)
    # 75th percentile
    percentiles_75_area_threshold_15.append(percentile_75_threshold_15)
   
    
    mean_max_dBZ_threshold_15.append(mean_threshold_15)
    mean_mean_dBZ_threshold_15.append(means_threshold_15)
 
    
    std_max_dBZ_threshold_15.append(std_threshold_15)
    std_mean_dBZ_threshold_15.append(stds_threshold_15)
   
    
    rel_time_threshold_15 = np.mean(sort_relative_times_threshold_15['relative_time'].values)
    rel_times_threshold_15.append(rel_time_threshold_15)
    rel_times1_threshold_15.append(rel_time_threshold_15)
    
     # time
    rel_times_area_threshold_15.append(rel_time_threshold_15)
# Out:
# /glade/work/noteng/conda-envs/tobac-env/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1556: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,

# %%
# maximum dBZ
mean_max_dBZ_threshold_10 = []
std_max_dBZ_threshold_10 = []
rel_times_threshold_10 = []

# mean dBZ
mean_mean_dBZ_threshold_10 = []
std_mean_dBZ_threshold_10 = []
rel_times1_threshold_10 = []

# area
percentiles_25_area_threshold_10 = []
percentiles_50_area_threshold_10 = []
percentiles_75_area_threshold_10 = []
rel_times_area_threshold_10 = []

for indexes, time in enumerate(np.unique(first_landfall_threshold_10['relative_time'])):
    # Sorting based on same relative times
    sort_relative_times_threshold_10 = first_landfall_threshold_10[first_landfall_threshold_10['relative_time'] == time]
    # Find each relative time associated with a particular reflectivity value
    # print(sort_relative_times['relative_time'].values, sort_relative_times['max dBZ'].values)
    
    mean_threshold_10 = np.mean(sort_relative_times_threshold_10['max dBZ'].values)
    means_threshold_10 = np.mean(sort_relative_times_threshold_10['mean dBZ'].values)
    
    
    std_threshold_10 = np.std(sort_relative_times_threshold_10['max dBZ'].values)
    stds_threshold_10 = np.std(sort_relative_times_threshold_10['mean dBZ'].values)
    
    
    # AREA
    # 25th percentile
    percentile_25_threshold_10 = np.nanpercentile(sort_relative_times_threshold_10['area($km^2$)'].values, 25)
     # 50th percentile
    percentile_50_threshold_10 = np.nanpercentile(sort_relative_times_threshold_10['area($km^2$)'].values, 50)
    # 75th percentile
    percentile_75_threshold_10 = np.nanpercentile(sort_relative_times_threshold_10['area($km^2$)'].values, 75)
       
    # 25th percentile
    percentiles_25_area_threshold_10.append(percentile_25_threshold_10)
    # 50th percentile
    percentiles_50_area_threshold_10.append(percentile_50_threshold_10)
    # 75th percentile
    percentiles_75_area_threshold_10.append(percentile_75_threshold_10)
    
    mean_max_dBZ_threshold_10.append(mean_threshold_10)
    mean_mean_dBZ_threshold_10.append(means_threshold_10)
    
    std_max_dBZ_threshold_10.append(std_threshold_10)
    std_mean_dBZ_threshold_10.append(stds_threshold_10)
    
    rel_time_threshold_10 = np.mean(sort_relative_times_threshold_10['relative_time'].values)
    # rel_time_threshold_10 = np.median(sort_relative_times_threshold_10['relative_time'].values)
    rel_times_threshold_10.append(rel_time_threshold_10)
    rel_times1_threshold_10.append(rel_time_threshold_10)
    
    # time
    rel_times_area_threshold_10.append(rel_time_threshold_10)

# %% [markdown]
# ## _MAXIMUM REFLECTIVITY_

# %%
len(first_landfall_threshold_10),len(first_landfall_threshold_15), len(first_landfall_threshold_20)
# Out:
# (1381, 2049, 1606)

# %%
fig, ax = plt.subplots(figsize=(12, 7))
X=np.arange(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']+1), 5)
# Y = np.arange(np.min(first_landfall_threshold_20['max dBZ']), np.max(first_landfall_threshold_20['max dBZ']),1)

for index, cell_ids in enumerate(np.unique(first_landfall_threshold_15['cell'])):
    cell_number10 = first_landfall_threshold_10[first_landfall_threshold_10['cell'] == cell_ids]
    cell_number15 = first_landfall_threshold_15[first_landfall_threshold_15['cell'] == cell_ids]
    cell_number20 = first_landfall_threshold_20[first_landfall_threshold_20['cell'] == cell_ids]

# # ax.scatter(rel_times_threshold_20, mean_max_dBZ_threshold_20, color='black', marker='o',)
# ax.errorbar(rel_times_threshold_5, mean_max_dBZ_threshold_5, fmt='k',label='threshold 5')
ax.errorbar(rel_times_threshold_10, mean_max_dBZ_threshold_10, fmt='red',label='threshold 10', linewidth=2)
ax.errorbar(rel_times_threshold_15, mean_max_dBZ_threshold_15, fmt='green',label='threshold 15', linewidth=2)
ax.errorbar(rel_times_threshold_20, mean_max_dBZ_threshold_20, fmt='blue',label='threshold 20', linewidth=2)

# # # Show the range of one standard deviation above and below the mean as a filled area
# upper_bound = np.array(mean_max_dBZ_threshold_5) + np.array(std_max_dBZ_threshold_5)
# lower_bound = np.array(mean_max_dBZ_threshold_5) - np.array(std_max_dBZ_threshold_5)
# ax.fill_between(rel_times_threshold_5, upper_bound, lower_bound, alpha=0.2, color='black')

upper_bound = np.array(mean_max_dBZ_threshold_10) + np.array(std_max_dBZ_threshold_10)
lower_bound = np.array(mean_max_dBZ_threshold_10) - np.array(std_max_dBZ_threshold_10)
ax.fill_between(rel_times_threshold_10, upper_bound, lower_bound, alpha=0.2, color='red')

upper_bound = np.array(mean_max_dBZ_threshold_15) + np.array(std_max_dBZ_threshold_15)
lower_bound = np.array(mean_max_dBZ_threshold_15) - np.array(std_max_dBZ_threshold_15)
ax.fill_between(rel_times_threshold_15, upper_bound, lower_bound, alpha=0.2, color='green')

upper_bound = np.array(mean_max_dBZ_threshold_20) + np.array(std_max_dBZ_threshold_20)
lower_bound = np.array(mean_max_dBZ_threshold_20) - np.array(std_max_dBZ_threshold_20)
ax.fill_between(rel_times_threshold_20, upper_bound, lower_bound, alpha=0.2, color='blue')

# set limit
ax.set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))
# ax.set_ylim(np.min(first_landfall_threshold_20['max dBZ']), np.max(first_landfall_threshold_20['max dBZ']))
# # set xticks and yticks
ax.set_xticks(X)
# ax.set_yticks(Y)
ax.invert_xaxis()
ax.set_xlabel('relative time (mins)', fontsize=15)
ax.set_ylabel('maximum reflectivity (dBz)', fontsize=15)
ax.set_title('TEMPORAL VARIATION OF MAXIMUM REFLECTIVITY', fontweight='bold', fontsize=18)
plt.grid(color='gray', alpha=0.1)
ax.legend()

# # # move the legend outside the plot area
# ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# ax.text(x=-6, y=46, s='CELL-IDs', fontweight='bold')
plt.xticks(rotation=45)

# ax.text(x=5, y=31, s='landfall', fontweight='bold');
fig.savefig('./images/all-cells-that-made-landfall/4am-5am/maximum-dBZ.png', dpi=500, bbox_inches='tight');

# %% [markdown]
# # MEAN REFLECTIVITY

# %%
fig, ax = plt.subplots(figsize=(12, 7))
X=np.arange(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']+1), 5)
# Y = np.arange(np.min(first_landfall_threshold_20['max dBZ']), np.max(first_landfall_threshold_20['max dBZ']),1)

for index, cell_ids in enumerate(np.unique(first_landfall_threshold_15['cell'])):
    # cell_number5 = first_landfall_threshold_5[first_landfall_threshold_5['cell'] == cell_ids]
    cell_number10 = first_landfall_threshold_10[first_landfall_threshold_10['cell'] == cell_ids]
    cell_number15 = first_landfall_threshold_15[first_landfall_threshold_15['cell'] == cell_ids]
    cell_number20 = first_landfall_threshold_20[first_landfall_threshold_20['cell'] == cell_ids]



# # ax.scatter(rel_times_threshold_20, mean_max_dBZ_threshold_20, color='black', marker='o',)
# ax.errorbar(rel_times_threshold_5, mean_mean_dBZ_threshold_5, fmt='k',label='threshold 5')
ax.errorbar(rel_times_threshold_10, mean_mean_dBZ_threshold_10, fmt='red',label='threshold 10', linewidth=2)
ax.errorbar(rel_times_threshold_15, mean_mean_dBZ_threshold_15, fmt='green',label='threshold 15', linewidth=2)
ax.errorbar(rel_times_threshold_20, mean_mean_dBZ_threshold_20, fmt='blue',label='threshold 20', linewidth=2)

# # # Show the range of one standard deviation above and below the mean as a filled area
# upper_bound = np.array(mean_mean_dBZ_threshold_5) + np.array(std_mean_dBZ_threshold_5)
# lower_bound = np.array(mean_mean_dBZ_threshold_5) - np.array(std_mean_dBZ_threshold_5)
# ax.fill_between(rel_times_threshold_5, upper_bound, lower_bound, alpha=0.2, color='black')

upper_bound = np.array(mean_mean_dBZ_threshold_10) + np.array(std_mean_dBZ_threshold_10)
lower_bound = np.array(mean_mean_dBZ_threshold_10) - np.array(std_mean_dBZ_threshold_10)
ax.fill_between(rel_times_threshold_10, upper_bound, lower_bound, alpha=0.2, color='red')

upper_bound = np.array(mean_mean_dBZ_threshold_15) + np.array(std_mean_dBZ_threshold_15)
lower_bound = np.array(mean_mean_dBZ_threshold_15) - np.array(std_mean_dBZ_threshold_15)
ax.fill_between(rel_times_threshold_15, upper_bound, lower_bound, alpha=0.2, color='green')

upper_bound = np.array(mean_mean_dBZ_threshold_20) + np.array(std_mean_dBZ_threshold_20)
lower_bound = np.array(mean_mean_dBZ_threshold_20) - np.array(std_mean_dBZ_threshold_20)
ax.fill_between(rel_times_threshold_20, upper_bound, lower_bound, alpha=0.2, color='blue')

# set limit
ax.set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))
# ax.set_ylim(np.min(first_landfall_threshold_20['max dBZ']), np.max(first_landfall_threshold_20['max dBZ']))
# # set xticks and yticks
ax.set_xticks(X)
# ax.set_yticks(Y)
ax.invert_xaxis()
ax.set_xlabel('relative time (mins)', fontsize=15)
ax.set_ylabel('mean reflectivity (dBz)', fontsize=15)
ax.set_title('TEMPORAL VARIATION OF MEAN REFLECTIVITY', fontweight='bold', fontsize=18)
plt.grid(color='gray', alpha=0.1)
ax.legend(loc=3)

# # # move the legend outside the plot area
# ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# ax.text(x=-6, y=46, s='CELL-IDs', fontweight='bold')
plt.xticks(rotation=45)

# ax.text(x=5, y=31, s='landfall', fontweight='bold');
fig.savefig('./images/all-cells-that-made-landfall/4am-5am/mean-dBZ.png', dpi=500, bbox_inches='tight');

# %% [markdown]
# # AREA

# %%
fig, ax = plt.subplots(figsize=(12, 7))
X=np.arange(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']+1), 5)

ax.plot(rel_times_area_threshold_10, percentiles_50_area_threshold_10, color='red', label='threshold 10')
ax.plot(rel_times_area_threshold_15, percentiles_50_area_threshold_15, color='green', label='threshold 15')
ax.plot(rel_times_area_threshold_20, percentiles_50_area_threshold_20, color='blue', label='threshold 20')


ax.fill_between(rel_times_area_threshold_10, percentiles_25_area_threshold_10, percentiles_75_area_threshold_10, alpha=0.2, color='red', linewidth=2)
ax.fill_between(rel_times_area_threshold_15, percentiles_25_area_threshold_15, percentiles_75_area_threshold_15, alpha=0.2, color='green', linewidth=2)
ax.fill_between(rel_times_area_threshold_20, percentiles_25_area_threshold_20, percentiles_75_area_threshold_20, alpha=0.2, color='blue', linewidth=2)

# # # # Show the range of one standard deviation above and below the mean as a filled area

# # set limit
ax.set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))

# # # set xticks and yticks
ax.set_xticks(X)
# # ax.set_yticks(Y)
ax.invert_xaxis()
ax.set_xlabel('relative time (mins)', fontsize=15)
ax.set_ylabel('area $(km^2)$', fontsize=15)
ax.set_title('TEMPORAL VARIATION OF AREA', fontweight='bold', fontsize=18)
plt.grid(color='gray', alpha=0.1)
ax.legend(loc=3)

# # # # move the legend outside the plot area
# # ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# # ax.text(x=-6, y=46, s='CELL-IDs', fontweight='bold')
plt.xticks(rotation=45);

# ax.text(x=5, y=31, s='landfall', fontweight='bold');
fig.savefig('./images/all-cells-that-made-landfall/4am-5am/area.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# ## _CALCULATING N_CELLS AS A FUNCTION OF RELATIVE TIME_

# %%
# df5 = first_landfall_threshold_5.copy()
df10 = first_landfall_threshold_10.copy()
df15 = first_landfall_threshold_15.copy()
df20 = first_landfall_threshold_20.copy()

# sort dataframe by relative time -- ascending order
# sorting_df5 = df5.sort_values(by=['relative_time'])
sorting_df10 = df10.sort_values(by=['relative_time'])
sorting_df15 = df15.sort_values(by=['relative_time'])
sorting_df20 = df20.sort_values(by=['relative_time'])

# get the relative time only
# relative_time5 = sorting_df5['relative_time']
relative_time10 = sorting_df10['relative_time']
relative_time15 = sorting_df15['relative_time']
relative_time20 = sorting_df20['relative_time']

# get the number of counts based on the relative time
# number_of_cell5 = relative_time5.value_counts()
# relative_times5 = number_of_cell5.index # get relative time
# number_cells5 = number_of_cell5.values # the number of cell based on relative time

number_of_cell10 = relative_time10.value_counts()
relative_times10 = number_of_cell10.index # get relative time
number_cells10 = number_of_cell10.values # the number of cell based on relative time

number_of_cell15 = relative_time15.value_counts()
relative_times15 = number_of_cell15.index # get relative time
number_cells15 = number_of_cell15.values # the number of cell based on relative time

number_of_cell20 = relative_time20.value_counts()
relative_times20 = number_of_cell20.index # get relative time
number_cells20 = number_of_cell20.values # the number of cell based on relative time

# len(relative_times), len(number_cells)
# all_cells_count_landfall5 = pd.DataFrame(data={'relative time(min)': relative_times5, 
#                                          'number cells': number_cells5})

all_cells_count_landfall10 = pd.DataFrame(data={'relative time(min)': relative_times10, 
                                         'number cells': number_cells10})

all_cells_count_landfall15 = pd.DataFrame(data={'relative time(min)': relative_times15, 
                                         'number cells': number_cells15})

all_cells_count_landfall20 = pd.DataFrame(data={'relative time(min)': relative_times20, 
                                         'number cells': number_cells20})

# %%
len(all_cells_count_landfall10) ,len(all_cells_count_landfall15), len(all_cells_count_landfall20)
# Out:
# (34, 53, 36)

# %%
fig, ax = plt.subplots(figsize=(12, 7))
X=np.arange(np.min(all_cells_count_landfall15['relative time(min)']), np.max(all_cells_count_landfall15['relative time(min)']+1), 5)
Y = np.arange(np.min(all_cells_count_landfall15['number cells']-1), np.max(all_cells_count_landfall15['number cells']),100)


# ax.plot(all_cells_count_landfall10['relative time(min)'], 
#                 np.log10(all_cells_count_landfall10['number cells']), color='red', label='Threshold 10', linewidth=2)
# ax.plot(all_cells_count_landfall15['relative time(min)'], 
#                 np.log10(all_cells_count_landfall15['number cells']),color='green',label='Threshold 15', linewidth=2)
# ax.plot(all_cells_count_landfall20['relative time(min)'], 
#                 np.log10(all_cells_count_landfall20['number cells']), color='blue', label='Threshold 20', linewidth=2)


ax.plot(all_cells_count_landfall10['relative time(min)'], 
                all_cells_count_landfall10['number cells'], color='red', label='Threshold 10', linewidth=2)
ax.plot(all_cells_count_landfall15['relative time(min)'], 
                all_cells_count_landfall15['number cells'],color='green',label='Threshold 15', linewidth=2)
ax.plot(all_cells_count_landfall20['relative time(min)'], 
                all_cells_count_landfall20['number cells'], color='blue', label='Threshold 20', linewidth=2)

# # Customize the y-tick labels
# current_ticks = ax.get_yticks()
# new_ticks = [round(np.power(10, tick), 1) for tick in current_ticks]
# ax.set_yticklabels(new_ticks)

# set y to log scale
ax.set_yscale("log")  


# Set the FixedLocator and FixedFormatter for the y-axis
# ax.yaxis.set_major_locator(FixedLocator(current_ticks))
# ax.yaxis.set_major_formatter(FixedFormatter(new_ticks))


# # set limit
ax.set_xlim(np.min(all_cells_count_landfall15['relative time(min)']), np.max(all_cells_count_landfall15['relative time(min)']))

# #set xticks and yticks
ax.set_xticks(X)
# ax.set_yticks(Y) 
ax.invert_xaxis()
ax.set_xlabel('relative time (mins)', fontsize=15)
ax.set_ylabel('Number of Cells', fontsize=15)
ax.set_title('CELL POPULATION GROWTH OVER TIME', fontweight='bold', fontsize=18)
ax.legend()
plt.grid(color='gray', alpha=0.1)
# # # # move the legend outside the plot area
ax.legend(loc='upper left')
plt.xticks(rotation=45);

# ax.text(x=4, y=-220, s='landfall', fontweight='bold')
fig.savefig('./images/all-cells-that-made-landfall/4am-5am/N-cells.png', dpi=500, bbox_inches='tight')

# %% [markdown]
# # Panel Plot

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(17.5, 10), sharex=True)
ax = ax.flatten()

# MAXIMUM dBZ
X=np.arange(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']+1), 5)

for index, cell_ids in enumerate(np.unique(first_landfall_threshold_15['cell'])):
    cell_number10 = first_landfall_threshold_10[first_landfall_threshold_10['cell'] == cell_ids]
    cell_number15 = first_landfall_threshold_15[first_landfall_threshold_15['cell'] == cell_ids]
    cell_number20 = first_landfall_threshold_20[first_landfall_threshold_20['cell'] == cell_ids]

ax[0].errorbar(rel_times_threshold_10, mean_max_dBZ_threshold_10, fmt='red',label='threshold 10', linewidth=2)
ax[0].errorbar(rel_times_threshold_15, mean_max_dBZ_threshold_15, fmt='green',label='threshold 15', linewidth=2)
ax[0].errorbar(rel_times_threshold_20, mean_max_dBZ_threshold_20, fmt='blue',label='threshold 20', linewidth=2)

# # # Show the range of one standard deviation above and below the mean as a filled area
upper_bound = np.array(mean_max_dBZ_threshold_10) + np.array(std_max_dBZ_threshold_10)
lower_bound = np.array(mean_max_dBZ_threshold_10) - np.array(std_max_dBZ_threshold_10)
ax[0].fill_between(rel_times_threshold_10, upper_bound, lower_bound, alpha=0.2, color='red')

upper_bound = np.array(mean_max_dBZ_threshold_15) + np.array(std_max_dBZ_threshold_15)
lower_bound = np.array(mean_max_dBZ_threshold_15) - np.array(std_max_dBZ_threshold_15)
ax[0].fill_between(rel_times_threshold_15, upper_bound, lower_bound, alpha=0.2, color='green')

upper_bound = np.array(mean_max_dBZ_threshold_20) + np.array(std_max_dBZ_threshold_20)
lower_bound = np.array(mean_max_dBZ_threshold_20) - np.array(std_max_dBZ_threshold_20)
ax[0].fill_between(rel_times_threshold_20, upper_bound, lower_bound, alpha=0.2, color='blue')

# set limit
ax[0].set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))
# ax.set_ylim(np.min(first_landfall_threshold_20['max dBZ']), np.max(first_landfall_threshold_20['max dBZ']))
# # set xticks and yticks
ax[0].set_facecolor('white')
ax[0].invert_xaxis()
ax[0].set_ylabel('maximum reflectivity (dBz)', fontsize=11)
ax[0].set_title('TEMPORAL VARIATION OF MAXIMUM REFLECTIVITY', fontweight='bold', fontsize=12)
ax[0].grid(color='gray', alpha=0.1)
# ax[0].legend()
ax[0].text(x=255, y=46.75, s='(a)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))


# MEAN dBZ
ax[1].errorbar(rel_times_threshold_10, mean_mean_dBZ_threshold_10, fmt='red',label='threshold 10', linewidth=2)
ax[1].errorbar(rel_times_threshold_15, mean_mean_dBZ_threshold_15, fmt='green',label='threshold 15', linewidth=2)
ax[1].errorbar(rel_times_threshold_20, mean_mean_dBZ_threshold_20, fmt='blue',label='threshold 20', linewidth=2)

# # # Show the range of one standard deviation above and below the mean as a filled area
upper_bound = np.array(mean_mean_dBZ_threshold_10) + np.array(std_mean_dBZ_threshold_10)
lower_bound = np.array(mean_mean_dBZ_threshold_10) - np.array(std_mean_dBZ_threshold_10)
ax[1].fill_between(rel_times_threshold_10, upper_bound, lower_bound, alpha=0.2, color='red')

upper_bound = np.array(mean_mean_dBZ_threshold_15) + np.array(std_mean_dBZ_threshold_15)
lower_bound = np.array(mean_mean_dBZ_threshold_15) - np.array(std_mean_dBZ_threshold_15)
ax[1].fill_between(rel_times_threshold_15, upper_bound, lower_bound, alpha=0.2, color='green')

upper_bound = np.array(mean_mean_dBZ_threshold_20) + np.array(std_mean_dBZ_threshold_20)
lower_bound = np.array(mean_mean_dBZ_threshold_20) - np.array(std_mean_dBZ_threshold_20)
ax[1].fill_between(rel_times_threshold_20, upper_bound, lower_bound, alpha=0.2, color='blue')

# set limit
ax[1].set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))
# # set xticks and yticks
# ax.set_xticks(X)
ax[1].set_facecolor('white')
ax[1].invert_xaxis()
ax[1].set_ylabel('mean reflectivity (dBz)', fontsize=11)
ax[1].set_title('TEMPORAL VARIATION OF MEAN REFLECTIVITY', fontweight='bold', fontsize=12)
ax[1].grid(color='gray', alpha=0.1)
# ax[1].legend(loc=3)
ax[1].text(x=255, y=16.9, s='(b)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))


# AREA
ax[2].plot(rel_times_area_threshold_10, percentiles_50_area_threshold_10, color='red', label='threshold 10', linewidth=2)
ax[2].plot(rel_times_area_threshold_15, percentiles_50_area_threshold_15, color='green', label='threshold 15', linewidth=2)
ax[2].plot(rel_times_area_threshold_20, percentiles_50_area_threshold_20, color='blue', label='threshold 20', linewidth=2)
ax[2].fill_between(rel_times_area_threshold_10, percentiles_25_area_threshold_10, percentiles_75_area_threshold_10, alpha=0.2, color='red')
ax[2].fill_between(rel_times_area_threshold_15, percentiles_25_area_threshold_15, percentiles_75_area_threshold_15, alpha=0.2, color='green')
ax[2].fill_between(rel_times_area_threshold_20, percentiles_25_area_threshold_20, percentiles_75_area_threshold_20, alpha=0.2, color='blue')
# # set limit
# ax[2].set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))

# # # # set xticks and yticks
# ax[2].set_xticks(X)
ax[2].invert_xaxis()
ax[2].set_facecolor('white')
ax[2].set_xlabel('relative time (mins)', fontsize=11)
ax[2].set_ylabel('area $(km^2)$', fontsize=11)
ax[2].set_title('TEMPORAL VARIATION OF AREA', fontweight='bold', fontsize=12)
ax[2].grid(color='gray', alpha=0.1)
ax[2].legend(loc=3)
ax[2].text(x=5, y=-40, s='LF', fontweight='bold')
ax[2].text(x=255, y=292.5, s='(c)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))



# N - CELLLS
# ax[3].plot(all_cells_count_landfall10['relative time(min)'], 
#                 np.log10(all_cells_count_landfall10['number cells']), color='red', label='Threshold 10', linewidth=2)
# ax[3].plot(all_cells_count_landfall15['relative time(min)'], 
#                 np.log10(all_cells_count_landfall15['number cells']),color='green',label='Threshold 15', linewidth=2)
# ax[3].plot(all_cells_count_landfall20['relative time(min)'], 
#                 np.log10(all_cells_count_landfall20['number cells']), color='blue', label='Threshold 20', linewidth=2)

# ax[3].plot(all_cells_count_landfall10['relative time(min)'], 
#                 all_cells_count_landfall10['number cells'], color='red', label='Threshold 10', linewidth=2)
# ax[3].plot(all_cells_count_landfall15['relative time(min)'], 
#                 all_cells_count_landfall15['number cells'],color='green',label='Threshold 15', linewidth=2)
# ax[3].plot(all_cells_count_landfall20['relative time(min)'], 
#                 all_cells_count_landfall20['number cells'], color='blue', label='Threshold 20', linewidth=2)



ax[3].plot(all_cells_count_landfall10['relative time(min)'], 
                all_cells_count_landfall10['number cells'], color='red', label='Threshold 10', linewidth=2)
ax[3].plot(all_cells_count_landfall15['relative time(min)'], 
                all_cells_count_landfall15['number cells'],color='green',label='Threshold 15', linewidth=2)
ax[3].plot(all_cells_count_landfall20['relative time(min)'], 
                all_cells_count_landfall20['number cells'], color='blue', label='Threshold 20', linewidth=2)

# # set limit
ax[3].set_xlim(np.min(all_cells_count_landfall15['relative time(min)']), np.max(all_cells_count_landfall15['relative time(min)']))


# # Customize the y-tick labels
# current_ticks = ax[3].get_yticks()
# new_ticks = [round(np.power(10, tick), 1) for tick in current_ticks]
# # ax[3].set_yticklabels(new_ticks)
# # Set the FixedLocator and FixedFormatter for the y-axis
# ax[3].yaxis.set_major_locator(FixedLocator(current_ticks))
# ax[3].yaxis.set_major_formatter(FixedFormatter(new_ticks))



# #set xticks and yticks
# ax[3].set_xticks(X)
ax[3].set_facecolor('white')
ax[3].invert_xaxis()
ax[3].set_xlabel('relative time (mins)', fontsize=11)
ax[3].set_ylabel('Number of Cells', fontsize=11)
ax[3].set_title('CELL POPULATION GROWTH OVER TIME', fontweight='bold', fontsize=12)
# ax[3].legend()
ax[3].grid(color='gray', alpha=0.1)
# # # # move the legend outside the plot area
ax[3].legend(loc='lower right')
ax[3].text(x=5, y=0.36, s='LF', fontweight='bold')

ax[3].text(x=255, y=540, s='(d)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))

ax[3].set_yscale('log')

fig.suptitle('TIME SERIES REFLECTIVITY RELATIVE TO LANDFALL', fontsize=20, fontweight='bold');
fig.savefig('./images/all-cells-that-made-landfall/4am-5am/panel-plot-time-series-reflectivity-to-landfall.png', dpi=500, bbox_inches='tight')

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(17.5, 10), sharex=True)
ax = ax.flatten()

# MAXIMUM dBZ
X=np.arange(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']+1), 5)

for index, cell_ids in enumerate(np.unique(first_landfall_threshold_15['cell'])):
    cell_number10 = first_landfall_threshold_10[first_landfall_threshold_10['cell'] == cell_ids]
    cell_number15 = first_landfall_threshold_15[first_landfall_threshold_15['cell'] == cell_ids]
    cell_number20 = first_landfall_threshold_20[first_landfall_threshold_20['cell'] == cell_ids]

ax[0].errorbar(rel_times_threshold_10, mean_max_dBZ_threshold_10, fmt='red',label='threshold 10', linewidth=2)
ax[0].errorbar(rel_times_threshold_15, mean_max_dBZ_threshold_15, fmt='green',label='threshold 15', linewidth=2)
ax[0].errorbar(rel_times_threshold_20, mean_max_dBZ_threshold_20, fmt='blue',label='threshold 20', linewidth=2)

# # # Show the range of one standard deviation above and below the mean as a filled area
upper_bound = np.array(mean_max_dBZ_threshold_10) + np.array(std_max_dBZ_threshold_10)
lower_bound = np.array(mean_max_dBZ_threshold_10) - np.array(std_max_dBZ_threshold_10)
ax[0].fill_between(rel_times_threshold_10, upper_bound, lower_bound, alpha=0.2, color='red')

upper_bound = np.array(mean_max_dBZ_threshold_15) + np.array(std_max_dBZ_threshold_15)
lower_bound = np.array(mean_max_dBZ_threshold_15) - np.array(std_max_dBZ_threshold_15)
ax[0].fill_between(rel_times_threshold_15, upper_bound, lower_bound, alpha=0.2, color='green')

upper_bound = np.array(mean_max_dBZ_threshold_20) + np.array(std_max_dBZ_threshold_20)
lower_bound = np.array(mean_max_dBZ_threshold_20) - np.array(std_max_dBZ_threshold_20)
ax[0].fill_between(rel_times_threshold_20, upper_bound, lower_bound, alpha=0.2, color='blue')

# set limit
ax[0].set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))
# ax.set_ylim(np.min(first_landfall_threshold_20['max dBZ']), np.max(first_landfall_threshold_20['max dBZ']))
# # set xticks and yticks
ax[0].set_facecolor('white')
ax[0].invert_xaxis()
ax[0].set_ylabel('maximum reflectivity (dBz)', fontsize=11)
# ax[0].set_title('TEMPORAL VARIATION OF MAXIMUM REFLECTIVITY', fontweight='bold', fontsize=12)
ax[0].grid(color='gray', alpha=0.1)
# ax[0].legend()
ax[0].text(x=255, y=46.75, s='(a)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))


# MEAN dBZ
ax[1].errorbar(rel_times_threshold_10, mean_mean_dBZ_threshold_10, fmt='red',label='threshold 10', linewidth=2)
ax[1].errorbar(rel_times_threshold_15, mean_mean_dBZ_threshold_15, fmt='green',label='threshold 15', linewidth=2)
ax[1].errorbar(rel_times_threshold_20, mean_mean_dBZ_threshold_20, fmt='blue',label='threshold 20', linewidth=2)

# # # Show the range of one standard deviation above and below the mean as a filled area
upper_bound = np.array(mean_mean_dBZ_threshold_10) + np.array(std_mean_dBZ_threshold_10)
lower_bound = np.array(mean_mean_dBZ_threshold_10) - np.array(std_mean_dBZ_threshold_10)
ax[1].fill_between(rel_times_threshold_10, upper_bound, lower_bound, alpha=0.2, color='red')

upper_bound = np.array(mean_mean_dBZ_threshold_15) + np.array(std_mean_dBZ_threshold_15)
lower_bound = np.array(mean_mean_dBZ_threshold_15) - np.array(std_mean_dBZ_threshold_15)
ax[1].fill_between(rel_times_threshold_15, upper_bound, lower_bound, alpha=0.2, color='green')

upper_bound = np.array(mean_mean_dBZ_threshold_20) + np.array(std_mean_dBZ_threshold_20)
lower_bound = np.array(mean_mean_dBZ_threshold_20) - np.array(std_mean_dBZ_threshold_20)
ax[1].fill_between(rel_times_threshold_20, upper_bound, lower_bound, alpha=0.2, color='blue')

# set limit
ax[1].set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))
# # set xticks and yticks
# ax.set_xticks(X)
ax[1].set_facecolor('white')
ax[1].invert_xaxis()
ax[1].set_ylabel('mean reflectivity (dBz)', fontsize=11)
# ax[1].set_title('TEMPORAL VARIATION OF MEAN REFLECTIVITY', fontweight='bold', fontsize=12)
ax[1].grid(color='gray', alpha=0.1)
# ax[1].legend(loc=3)
ax[1].text(x=255, y=16.9, s='(b)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))


# AREA
ax[2].plot(rel_times_area_threshold_10, percentiles_50_area_threshold_10, color='red', label='threshold 10', linewidth=2)
ax[2].plot(rel_times_area_threshold_15, percentiles_50_area_threshold_15, color='green', label='threshold 15', linewidth=2)
ax[2].plot(rel_times_area_threshold_20, percentiles_50_area_threshold_20, color='blue', label='threshold 20', linewidth=2)
ax[2].fill_between(rel_times_area_threshold_10, percentiles_25_area_threshold_10, percentiles_75_area_threshold_10, alpha=0.2, color='red')
ax[2].fill_between(rel_times_area_threshold_15, percentiles_25_area_threshold_15, percentiles_75_area_threshold_15, alpha=0.2, color='green')
ax[2].fill_between(rel_times_area_threshold_20, percentiles_25_area_threshold_20, percentiles_75_area_threshold_20, alpha=0.2, color='blue')
# # set limit
# ax[2].set_xlim(np.min(first_landfall_threshold_15['relative_time']), np.max(first_landfall_threshold_15['relative_time']))

# # # # set xticks and yticks
# ax[2].set_xticks(X)
ax[2].invert_xaxis()
ax[2].set_facecolor('white')
ax[2].set_xlabel('relative time (mins)', fontsize=11)
ax[2].set_ylabel('area $(km^2)$', fontsize=11)
# ax[2].set_title('TEMPORAL VARIATION OF AREA', fontweight='bold', fontsize=12)
ax[2].grid(color='gray', alpha=0.1)
ax[2].legend(loc=3)
ax[2].text(x=5, y=-40, s='LF', fontweight='bold')
ax[2].text(x=255, y=292.5, s='(c)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))


# N - CELLLS
# ax[3].plot(all_cells_count_landfall10['relative time(min)'], 
#                 np.log10(all_cells_count_landfall10['number cells']), color='red', label='Threshold 10', linewidth=2)
# ax[3].plot(all_cells_count_landfall15['relative time(min)'], 
#                 np.log10(all_cells_count_landfall15['number cells']),color='green',label='Threshold 15', linewidth=2)
# ax[3].plot(all_cells_count_landfall20['relative time(min)'], 
#                 np.log10(all_cells_count_landfall20['number cells']), color='blue', label='Threshold 20', linewidth=2)

# ax[3].plot(all_cells_count_landfall10['relative time(min)'], 
#                 all_cells_count_landfall10['number cells'], color='red', label='Threshold 10', linewidth=2)
# ax[3].plot(all_cells_count_landfall15['relative time(min)'], 
#                 all_cells_count_landfall15['number cells'],color='green',label='Threshold 15', linewidth=2)
# ax[3].plot(all_cells_count_landfall20['relative time(min)'], 
#                 all_cells_count_landfall20['number cells'], color='blue', label='Threshold 20', linewidth=2)



ax[3].plot(all_cells_count_landfall10['relative time(min)'], 
                all_cells_count_landfall10['number cells'], color='red', label='Threshold 10', linewidth=2)
ax[3].plot(all_cells_count_landfall15['relative time(min)'], 
                all_cells_count_landfall15['number cells'],color='green',label='Threshold 15', linewidth=2)
ax[3].plot(all_cells_count_landfall20['relative time(min)'], 
                all_cells_count_landfall20['number cells'], color='blue', label='Threshold 20', linewidth=2)

# # set limit
ax[3].set_xlim(np.min(all_cells_count_landfall15['relative time(min)']), np.max(all_cells_count_landfall15['relative time(min)']))


# # Customize the y-tick labels
# current_ticks = ax[3].get_yticks()
# new_ticks = [round(np.power(10, tick), 1) for tick in current_ticks]
# # ax[3].set_yticklabels(new_ticks)
# # Set the FixedLocator and FixedFormatter for the y-axis
# ax[3].yaxis.set_major_locator(FixedLocator(current_ticks))
# ax[3].yaxis.set_major_formatter(FixedFormatter(new_ticks))



# #set xticks and yticks
# ax[3].set_xticks(X)
ax[3].set_facecolor('white')
ax[3].invert_xaxis()
ax[3].set_xlabel('relative time (mins)', fontsize=11)
ax[3].set_ylabel('Number of Cells', fontsize=11)
# ax[3].set_title('CELL POPULATION GROWTH OVER TIME', fontweight='bold', fontsize=12)
# ax[3].legend()
ax[3].grid(color='gray', alpha=0.1)
# # # # move the legend outside the plot area
ax[3].legend(loc='lower right')
ax[3].text(x=5, y=0.36, s='LF', fontweight='bold')

ax[3].text(x=255, y=540, s='(d)', fontweight='bold', fontsize=15, bbox = dict(facecolor = 'white', alpha = 0.5))

ax[3].set_yscale('log')

# fig.suptitle('TIME SERIES REFLECTIVITY RELATIVE TO LANDFALL', fontsize=20, fontweight='bold');
fig.savefig('./images/all-cells-that-made-landfall/4am-5am/pub-panel-plot-time-series-reflectivity-to-landfall.png', dpi=500, bbox_inches='tight')
